# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
TEST_DATASET = 'test.csv'
TRAIN_DATASET = 'train.csv'

# %%
train_data = pd.read_csv(TRAIN_DATASET, sep = ',')
train_data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %% [markdown]
# Приведем данные в колонках Rooms и HouseFloor к типу int64.

# %%
train_data[['Rooms', 'HouseFloor']] = train_data[['Rooms', 'HouseFloor']].astype('int64')
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  int64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  int64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
# ...

# %% [markdown]
# ### Пропуски

# %% [markdown]
# Для пропуском используем значение медианы, так как Healthcare_1 и LifeSquare количественные переменные.

# %%
medians = train_data[['LifeSquare', 'Healthcare_1']].median()
medians
# Out:
# LifeSquare       32.78126
# Healthcare_1    900.00000
# dtype: float64

# %%
train_data[['LifeSquare', 'Healthcare_1']] = train_data[['LifeSquare', 'Healthcare_1']].fillna(medians)

# %% [markdown]
# ### Выбросы

# %%
train_data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     36.266040
# std     4859.01902     43.587592      0.839512     21.058732     76.609981
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     25.527399
# 50%     8394.50000     36.000000      2.000000     52.513310     32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625     41.427234
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [markdown]
# #### Rooms

# %%
train_data['Rooms'].describe()
# Out:
# count    10000.000000
# mean         1.890500
# std          0.839512
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max         19.000000
# Name: Rooms, dtype: float64

# %%
train_data['Rooms'].median()
# Out:
# 2.0

# %%
rooms_max = np.quantile(train_data['Rooms'], q=0.975)
rooms_max
# Out:
# 3.0

# %%
rooms_min = np.quantile(train_data['Rooms'], q=0.025)
rooms_min
# Out:
# 1.0

# %%
condition = (train_data['Rooms'] > rooms_max) | (train_data['Rooms'] < rooms_min)
train_data[condition]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 77     2435          85      4   65.559834   47.696255            6.0      6
# 120    9703          15      4   98.686703   57.307058           15.0     10
# 286     689          30      4   94.164934   60.322255           10.0      8
# 377    5927          57     10   59.056975   36.223072           10.0     22
# 385   14888          69      4   98.385446   76.081776            9.0     14
# ...     ...         ...    ...         ...         ...            ...    ...
# 9607   2095          55      4   94.652198   58.206761           10.0      3
# 9699   4971         169      5  117.855969   76.561318            9.0     12
# 9852  16641         111      4  117.201937   69.898092           14.0      4
# 9910  16568          27      4  200.334539  201.627361           25.0      1
# 9918  14904          34      4  104.049130   99.788387           10.0      8
#
# ...

# %%
train_data.loc[condition, 'Rooms'] = train_data['Rooms'].median()
train_data['Rooms'].describe()
# Out:
# count    10000.000000
# mean         1.853000
# std          0.756603
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: Rooms, dtype: float64
